# %%
import requests

url = "https://currency-exchange.p.rapidapi.com/listquotes"

headers = {
    "X-RapidAPI-Key": "9b1c46ccf7msh0261a2b49fac25ep10b9f8jsn62f163dca628",
    "X-RapidAPI-Host": "currency-exchange.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# ["SGD","MYR","EUR","USD","AUD","JPY","CNH","HKD","CAD","INR","DKK","GBP","RUB","NZD","MXN","IDR","TWD","THB","VND"]

# %%
import requests

url = "https://currency-exchange.p.rapidapi.com/exchange"

querystring = {"from":"SGD","to":"MYR","q":"1.0"}

headers = {
	"X-RapidAPI-Key": "9b1c46ccf7msh0261a2b49fac25ep10b9f8jsn62f163dca628",
	"X-RapidAPI-Host": "currency-exchange.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# 3.2343640610000004

# %%
import requests

url = "https://hotels-com-provider.p.rapidapi.com/v2/hotels/search"

querystring = {"domain":"AE","sort_order":"REVIEW","locale":"en_GB","checkout_date":"2023-09-27","region_id":"2872","adults_number":"1","checkin_date":"2023-09-26","available_filter":"SHOW_AVAILABLE_ONLY","meal_plan":"FREE_BREAKFAST","guest_rating_min":"8","price_min":"10","page_number":"1","children_ages":"4,0,15","amenities":"WIFI,PARKING","price_max":"500","lodging_type":"HOTEL,HOSTEL,APART_HOTEL","payment_type":"PAY_LATER,FREE_CANCELLATION","star_rating_ids":"3,4,5"}

headers = {
	"X-RapidAPI-Key": "9b1c46ccf7msh0261a2b49fac25ep10b9f8jsn62f163dca628",
	"X-RapidAPI-Host": "hotels-com-provider.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"__typename":"PropertySearchResults","filterMetadata":{"__typename":"PropertyFilterMetadata","amenities":[{"__typename":"PropertyAmenityValue","id":7},{"__typename":"PropertyAmenityValue","id":83},{"__typename":"PropertyAmenityValue","id":14},{"__typename":"PropertyAmenityValue","id":82},{"__typename":"PropertyAmenityValue","id":16},{"__typename":"PropertyAmenityValue","id":17},{"__typename":"PropertyAmenityValue","id":19},{"__typename":"PropertyAmenityValue","id":27},{"__typename":"PropertyAmenityValue","id":66},{"__typename":"PropertyAmenityValue","id":76},{"__typename":"PropertyAmenityValue","id":70},{"__typename":"PropertyAmenityValue","id":71},{"__typename":"PropertyAmenityValue","id":73},{"__typename":"PropertyAmenityValue","id":75},{"__typename":"PropertyAmenityValue","id":79},{"__typename":"PropertyAmenityValue","id":80},{"__typename":"PropertyAmenityValue","id":81},{"__typename":"PropertyAmenityValue","id":84},{"__typename":"PropertyAmenityValue","id":85}],"neighborhoods":[
# ...

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.sfgov.org", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.sfgov.org",
                 "gZmg4iarmENBTk1Vzsb94bnse",
                 username="xinyulia@kth.se",
                 password="Xw990504")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("ebsh-uavg", limit=2000000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.columns
# Out:
# Index(['fiscal_year', 'purchase_order', 'purchase_order_line',
#        'purchasing_department', 'purchasing_department_title',
#        'post_date_original', 'post_date_current', 'commodity_code',
#        'commodity_title', 'vendor_name', 'vendor_street', 'vendor_city',
#        'vendor_state', 'vendor_zip_code', 'vendor_phone',
#        'encumbered_quantity', 'encumbered_amount', 'vendor_contact',
#        'vendor_email', 'po_dt', 'agreement_no', 'agreement_title'],
#       dtype='object')

# %%
results_df.drop(columns=["purchase_order","purchase_order_line","purchasing_department_title","post_date_original",
                        "post_date_current","commodity_title","vendor_name","vendor_street","vendor_zip_code",
                        "vendor_phone","vendor_contact","vendor_email","agreement_no","agreement_title"], inplace=True)

# %%
results_df
# Out:
#         fiscal_year purchasing_department commodity_code vendor_city  \
# 0              1999                  DPT2         955815  PITTSBURGH
# 1              1999                  DPT2         955815  PITTSBURGH
# 2              2002                   ART         725010    PACIFICA
# 3              2002                   ART         725010        NAPA
# 4              2002                   ART         730078     ALAMEDA
# ...             ...                   ...            ...         ...
# 1999995        2019                   DPH          47581       DIXON
# 1999996        2019                   DPH          47595       DIXON
# 1999997        2019                   DPH          47582       DIXON
# 1999998        2019                   DPH          26940       DIXON
# 1999999        2019                   DPH          47541       DIXON
#
#         vendor_state encumbered_quantity encumbered_amount  \
# 0                 PA                0.00        2088625.00
# ...

# %%
results_df[results_df["agreement_no"].notnull()].head().T
# Out:
#                                                   1438987  \
# fiscal_year                                          2018
# purchase_order                                 0000023480
# purchase_order_line                                    01
# purchasing_department                                 AIR
# purchasing_department_title        AIR Airport Commission
# post_date_original                                    NaN
# post_date_current                                     NaN
# commodity_code                                Unspecified
# commodity_title                                       NaN
# vendor_name                  CAL-STEAM A WOLSELEY COMPANY
# vendor_street                               PO BOX 740827
# vendor_city                                   LOS ANGELES
# vendor_state                                           CA
# vendor_zip_code                                90074-0827
# vendor_phone                                          NaN
# ...

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.sfgov.org", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.sfgov.org",
                 "gZmg4iarmENBTk1Vzsb94bnse",
                 username="xinyulia@kth.se",
                 password="Xw990504")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("v3fv-x3ux", limit=10000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df[results_df.data.notnull()]
# Out:
#              source              sample_date     analyte  data  \
# 0        BAY#211_SL  2020-08-31T00:00:00.000      COLI_E    74
# 1       OCEAN#15_SL  2020-09-01T00:00:00.000  COLI_TOTAL  5475
# 2       OCEAN#17_SL  2020-08-31T00:00:00.000      COLI_E   <10
# 3     OCEAN#21.1_SL  2020-08-31T00:00:00.000      ENTERO   <10
# 4       OCEAN#18_SL  2020-08-31T00:00:00.000  COLI_TOTAL   <10
# ...             ...                      ...         ...   ...
# 7733  OCEAN#21.1_SL  2022-09-12T00:00:00.000  COLI_TOTAL   <10
# 7734  OCEAN#21.1_SL  2022-09-12T00:00:00.000      ENTERO   <10
# 7735  OCEAN#21.1_SL  2022-09-06T00:00:00.000  COLI_FECAL    <5
# 7736  OCEAN#21.1_SL  2022-09-06T00:00:00.000  COLI_TOTAL   <10
# 7737  OCEAN#21.1_SL  2022-09-06T00:00:00.000      ENTERO   <10
#
#                               uniqueid
# 0     00139E644FE04108821489A810D0AA9D
# 1     012C756E5C2B04D033C90223C81FA39F
# 2     099D69C8E528B6CA3D6619A4AAB9DAA0
# 3     0CCA828DB4EDEC54F457CF157B8DF458
# ...

# %%
bay211sl=results_df[results_df.source=='BAY#211_SL']
bay211sl_entero=bay211sl[bay211sl.analyte=='ENTERO'].sort_values(by=['sample_date'])

# %%
bay211sl_entero
# Out:
#           source              sample_date analyte data  \
# 313   BAY#211_SL  2020-07-27T00:00:00.000  ENTERO  <10
# 1321  BAY#211_SL  2020-08-03T00:00:00.000  ENTERO   20
# 452   BAY#211_SL  2020-08-03T00:00:00.000  ENTERO   20
# 1318  BAY#211_SL  2020-08-04T00:00:00.000  ENTERO  <10
# 475   BAY#211_SL  2020-08-04T00:00:00.000  ENTERO  <10
# ...          ...                      ...     ...  ...
# 7102  BAY#211_SL  2022-11-09T00:00:00.000  ENTERO  <10
# 5907  BAY#211_SL  2022-11-14T00:00:00.000  ENTERO  <10
# 5895  BAY#211_SL  2022-11-21T00:00:00.000  ENTERO  <10
# 4066  BAY#211_SL  2022-11-28T00:00:00.000  ENTERO  <10
# 3948  BAY#211_SL  2022-12-01T00:00:00.000  ENTERO   52
#
#                               uniqueid
# 313   9A209D82D173FBB69397D2707BDA7C3F
# 1321  00E2A30B60E5C60EBF679FEC1F2599A2
# 452   7B63589514FF26F4A87D9C308205DA68
# 1318  31FBFB8A8F19D3C360AE593EDE3B1C9C
# 475   C2EC251CABFBF03F09C7C67A9F6FBBBE
# ...                                ...
# ...

# %%
bay211sl.analyte.unique()
# Out:
# array(['COLI_E', 'COLI_TOTAL', 'ENTERO', 'COLI_FECAL'], dtype=object)

# %%
bay211sl.groupby(by=['analyte']).count()
# Out:
#             source  sample_date  data  uniqueid
# analyte
# COLI_E          56           56    56        56
# COLI_FECAL      98           98    98        98
# COLI_TOTAL     154          154   154       154
# ENTERO         154          154   154       154

# %%
pd.set_option('display.max_rows', 100)

# %%
results_df[results_df.data.notnull()].groupby(by=['source','analyte']).count()
# Out:
#                             sample_date  data  uniqueid
# source          analyte
# BAY#202.4_SL    COLI_E               52    52        52
#                 COLI_FECAL          106   106       106
#                 COLI_TOTAL          158   158       158
#                 ENTERO              158   158       158
# BAY#202.5_SL    COLI_E               50    50        50
#                 COLI_FECAL           95    95        95
#                 COLI_TOTAL          144   144       144
#                 ENTERO              145   145       145
# BAY#210.1_SL    COLI_E                4     4         4
#                 COLI_FECAL           93    93        93
#                 COLI_TOTAL           97    97        97
#                 ENTERO               97    97        97
# BAY#211_SL      COLI_E               56    56        56
#                 COLI_FECAL           98    98        98
#                 COLI_TOTAL          154   154       154
# ...

# %%
import xgboost as xgb

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.sfgov.org", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.sfgov.org",
                 "gZmg4iarmENBTk1Vzsb94bnse",
                 username="xinyulia@kth.se",
                 password="Xw990504")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("wg3w-h783", limit=800000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.columns
# Out:
# Index(['incident_datetime', 'incident_date', 'incident_time', 'incident_year',
#        'incident_day_of_week', 'report_datetime', 'row_id', 'incident_id',
#        'incident_number', 'report_type_code', 'report_type_description',
#        'filed_online', 'incident_code', 'incident_category',
#        'incident_subcategory', 'incident_description', 'resolution',
#        'police_district', 'cad_number', 'intersection', 'cnn',
#        'analysis_neighborhood', 'supervisor_district', 'latitude', 'longitude',
#        'point', ':@computed_region_jwn9_ihcz', ':@computed_region_26cr_cadq',
#        ':@computed_region_qgnn_b9vv', ':@computed_region_nqbw_i6c3',
#        ':@computed_region_h4ep_8xdi', ':@computed_region_n4xg_c4py',
#        ':@computed_region_jg9y_a9du'],
#       dtype='object')

# %%
#results_df.groupby(by=['incident_category']).count()

# %%
results_df.drop(columns=['incident_datetime','report_datetime','row_id','incident_id','incident_number',
                        'incident_code','incident_subcategory','incident_description','cad_number',
                        'intersection', 'cnn','point', ':@computed_region_jwn9_ihcz', ':@computed_region_26cr_cadq',
                        ':@computed_region_qgnn_b9vv', ':@computed_region_nqbw_i6c3',
                        ':@computed_region_h4ep_8xdi', ':@computed_region_n4xg_c4py',
                        ':@computed_region_jg9y_a9du'], inplace=True)

# %%
results_df.head().T
# Out:
#                                                0                        1  \
# incident_date            2021-07-25T00:00:00.000  2022-06-28T00:00:00.000
# incident_time                              00:00                    23:58
# incident_year                               2021                     2022
# incident_day_of_week                      Sunday                  Tuesday
# report_type_code                              II                       VS
# report_type_description         Coplogic Initial       Vehicle Supplement
# filed_online                                True                      NaN
# incident_category                  Larceny Theft           Other Offenses
# resolution                        Open or Active           Open or Active
# police_district                         Southern                Out of SF
# analysis_neighborhood                        NaN                      NaN
# supervisor_district                          NaN                      NaN
# ...

# %%
results_df.describe().T
# Out:
#                           count unique                      top    freq
# incident_date            669605   1800  2022-06-26T00:00:00.000     605
# incident_time            669605   1440                    00:00   19549
# incident_year            669605      5                     2018  152586
# incident_day_of_week     669605      7                   Friday  102540
# report_type_code         669605      4                       II  528345
# report_type_description  669605      6                  Initial  408518
# filed_online             134894      1                     True  134894
# incident_category        669046     49            Larceny Theft  204121
# resolution               669605      4           Open or Active  534904
# police_district          669605     11                  Central   99986
# analysis_neighborhood    634147     42                  Mission   67917
# supervisor_district      634147     11                        6  147961
# ...

# %%
results_df.groupby(by=['resolution']).count()
# Out:
#                       incident_date  incident_time  incident_year  \
# resolution
# Cite or Arrest Adult         129278         129278         129278
# Exceptional Adult              1751           1751           1751
# Open or Active               534904         534904         534904
# Unfounded                      3672           3672           3672
#
#                       incident_day_of_week  report_type_code  \
# resolution
# Cite or Arrest Adult                129278            129278
# Exceptional Adult                     1751              1751
# Open or Active                      534904            534904
# Unfounded                             3672              3672
#
#                       report_type_description  filed_online  \
# resolution
# Cite or Arrest Adult                   129278             0
# Exceptional Adult                        1751             0
# Open or Active                         534904        134894
# ...

# %%
results_df.groupby(by=['incident_category']).count()
# Out:
#                                               incident_date  incident_time  \
# incident_category
# Arson                                                  1918           1918
# Assault                                               40680          40680
# Burglary                                              37685          37685
# Case Closure                                           2772           2772
# Civil Sidewalks                                         888            888
# Courtesy Report                                        1958           1958
# Disorderly Conduct                                    11057          11057
# Drug Offense                                          16105          16105
# Drug Violation                                          231            231
# Embezzlement                                            861            861
# Fire Report                                             962            962
# ...
